# %%
cd ~/Code/Langley
# Out:
# /home/alstottj/Code/Langley

# %%
z = 5

# %%
import database as dbimport powerlawfrom scipy.stats import linregressimport Helix_databasesession = Helix_database.Session()

# %%
import networkximport pickleG = pickle.load(open('/data/alstottj/Langley/Network_parents.p'))C=networkx.connected_component_subgraphs(G.to_undirected())

# %%
def max_depth(G):    d = 0    for i in G.node:        d = max(d,G.node[i]['depth'])    return float(d)

# %%
ds_ris = asarray([q for q in session.query(db.LangleyParticipant)\               .filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None) \               .filter(db.LangleyParticipant.Distance_from_Parent!=None)\               .values(db.LangleyParticipant.Parent_Child_Registration_Interval_Corrected, \                       db.LangleyParticipant.Distance_from_Parent,\                       db.LangleyParticipant.Number_of_Children,\                       db.LangleyParticipant.Depth_in_Invite_Chain)])ds = ds_ris[:,1]ris = ds_ris[:,0]number_of_children = ds_ris[:,2]depths = ds_ris[:,3]

# %%
def odds_of_small_ris(x):    from random import sample    r = len(ris)    n = len(x)    m = median(x)    sims = 0    for i in range(1000):        x = sample(range(r), n)        if median(ris[x])<m:            sims+=1    return sims/1000.0

# %%
import matplotlib.cm as cmfor i in range(len(C)):    if networkx.number_of_nodes(C[i])>2:        d = max_depth(C[i])        figure()        title("Team %i, %i members, %.0f generations"%(i, len(C[i].node), d))        pos=networkx.spring_layout(C[i].to_undirected())        depth_colors = []        for j in C[i].nodes():            depth_percentage = C[i].node[j]['depth']/d            depth_colors.append(cm.jet(depth_percentage))        networkx.draw(C[i],pos,node_size=20,alpha=0.8,with_labels=False, node_color = depth_colors)        #text(.1, .1, "Number of Generations= "+str(d),transform = ax.transAxes)        if i%3==0:            savefig("figure%i.png"%z, dpi=300, bbox_inches='tight')            z+=1

# %%
team_sizes = numpy.zeros(len(C))for i in range(len(C)):    team_sizes[i] = networkx.number_of_nodes(C[i])fig = figure()ax = fig.add_subplot(111)title("Team Size Distribution")xlabel("Team Size (Number of Members)")ylabel("p(Size)")text(.2, .8, "Number of teams: "+str(len(C)), transform = ax.transAxes)i,j = powerlaw.plot_pdf(team_sizes)#savefig("figure%i.png"%z, dpi=300, bbox_inches='tight')z+=1sigmas = asarray(G.out_degree().values())have_children = float(len(sigmas[sigmas>0]))/float(len(sigmas))have_children_string = "%.2f"%(have_children*100)figure()title("Number of Shares Distribution")xlabel("Number of Shares for an Individual")ylabel("p(Number of Shares)")text(.2, .8, "Number of Participants: "+str(len(G.node))+"\nOnly the "+have_children_string+"% participants with recruits shown", transform = ax.transAxes)#hist(sigmas, bins=100)#figure()i,j = powerlaw.plot_pdf(sigmas[sigmas>0])#savefig("figure%i.png"%z, dpi=300, bbox_inches='tight')z+=1depths = numpy.array(networkx.get_node_attributes(G, 'depth').values())team_starters = float(len(depths[depths==0]))/float(len(depths))team_starters_string = "%.2f"%(team_starters*100)figure()title("Recruitment Tree Depth Distribution")xlabel("Depth in Recruitment Tree for an Individual")ylabel("p(Depth)")text(.2, .8, team_starters_string+"% who started their own team not included", transform = ax.transAxes)#hist(depths)#figure()i,j = powerlaw.plot_pdf(depths[depths>0])figure()title("Recruitment Tree Depth Distribution")xlabel("Depth in Recruitment Tree for an Individual")ylabel("p(Depth)")i = hist(depths, normed=False, bins=7)savefig("figure%i.png"%z, dpi=300, bbox_inches='tight')z+=1

# %% [markdown]
# Number of Shares with Generation in the Invite Chain==========###The median number of shares at each invite generation is zero, but the first generation has far more sharing

# %%
sigmas = asarray([q for q in session.query(db.LangleyParticipant).values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()depths = asarray([q for q in session.query(db.LangleyParticipant).values(getattr(db.LangleyParticipant, 'Depth_in_Invite_Chain'))]).flatten()fig = plt.figure()ax = fig.add_subplot(111)ax.scatter(depths, sigmas)xlabel("Generation in Invite Tree")ylabel("Number of Shares")ylim(-1, ylim()[1])fig = plt.figure()ax = fig.add_subplot(111)d0 = sigmas[depths==0]d1 = sigmas[depths==1]d2 = sigmas[depths==2]d3 = sigmas[depths==3]d4 = sigmas[depths==4]d5 = sigmas[depths==5]d6 = sigmas[depths==6]ax.plot(arange(7), [mean(d0), mean(d1), mean(d2), mean(d3), mean(d4), mean(d5), mean(d6)])xlabel("Generation in Invite Tree")ylabel("Average Number of Shares")savefig("figure%i.png"%z, dpi=300, bbox_inches='tight')z+=1fig = plt.figure()ax = fig.add_subplot(111)q = ax.boxplot([d0, d1, d2, d3, d4, d5, d6])xlabel("Generation in Invite Tree")ylabel("Number of Shares")
# Out:
# &lt;matplotlib.text.Text at 0x187131d0&gt;

# %%
sigmas = asarray([q for q in session.query(db.LangleyParticipant).values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()sigma_follower = asarray([q for q in session.query(db.LangleyParticipant).filter_by(Has_Parent=True).values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()sigma_starter = asarray([q for q in session.query(db.LangleyParticipant).filter_by(Has_Parent=False).values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()Stds = (std(sigma_starter), std(sigma_follower))fig = plt.figure()ax = fig.add_subplot(111)ind = array([1,2.5])width = 1ax.bar(ind, [mean(sigma_starter>0), mean(sigma_follower>0)], width=width)ylim(0,1)#title('Mean Number of Recruits for Team Starters and Team Followers')title("Team Starters More Likely to Share at All")ylabel('Probability of Sharing')ax.set_xticks(ind+.5*width)ax.set_xticklabels( ('Team Starters', 'Followers') )xlim(ind[0]-.5*width, ind[1]+1.5*width)savefig("figure%i.png"%z, dpi=300, bbox_inches='tight')fig = plt.figure()ax = fig.add_subplot(111)ind = array([1,2.5])width = 1ax.bar(ind, [mean(sigma_starter), mean(sigma_follower)], yerr=Stds, width=width)ylim(0,ylim()[1])title("Team Starters Share More")ylabel('Mean Number of Shares')ax.set_xticks(ind+.5*width)ax.set_xticklabels( ('Team Starters', 'Followers') )xlim(ind[0]-.5*width, ind[1]+1.5*width)savefig("figure%i.png"%z, dpi=300, bbox_inches='tight')z+=1fig = plt.figure()ax = fig.add_subplot(111)ys, xs = powerlaw.cumulative_distribution_function(sigma_starter, survival=True)yf, xf = powerlaw.cumulative_distribution_function(sigma_follower, survival=True)y, x = powerlaw.cumulative_distribution_function(sigmas, survival=True)handles = {}handles["All"] = ax.plot(x, y, label="All", linewidth=4, color='k')handles["Team Starters"] = ax.plot(xs, ys, label="Team Starters")handles["Followers"] = ax.plot(xf, yf, label="Followers")ax.set_xscale("log")ax.set_yscale("log")xlabel("Number of Shares")ylabel("p(Number of Shares>x)")handles, labels = ax.get_legend_handles_labels()ax.legend(handles[::-1], labels[::-1], loc=1)savefig("figure%i.png"%z, dpi=300, bbox_inches='tight')z+=1

# %%
r1 = asarray([q for q in session.query(db.LangleyParticipant).filter_by(Relationship_with_Parent=1).values(getattr(db.LangleyParticipant, 'Has_Parent'))]).flatten()r1p = 1-float(sum(r1))/len(r1)r2 = asarray([q for q in session.query(db.LangleyParticipant).filter_by(Relationship_with_Parent=2).values(getattr(db.LangleyParticipant, 'Has_Parent'))]).flatten()r2p = 1-float(sum(r2))/len(r2)r3 = asarray([q for q in session.query(db.LangleyParticipant).filter_by(Relationship_with_Parent=3).values(getattr(db.LangleyParticipant, 'Has_Parent'))]).flatten()r3p = 1-float(sum(r3))/len(r3)r4 = asarray([q for q in session.query(db.LangleyParticipant).filter_by(Relationship_with_Parent=4).values(getattr(db.LangleyParticipant, 'Has_Parent'))]).flatten()r4p = 1-float(sum(r4))/len(r4)r5 = asarray([q for q in session.query(db.LangleyParticipant).filter_by(Relationship_with_Parent=5).values(getattr(db.LangleyParticipant, 'Has_Parent'))]).flatten()r5p = 1-float(sum(r5))/len(r5)r100 = asarray([q for q in session.query(db.LangleyParticipant).filter_by(Relationship_with_Parent=100).values(getattr(db.LangleyParticipant, 'Has_Parent'))]).flatten()r100p = 1-float(sum(r100))/len(r100)fig = plt.figure()ax = fig.add_subplot(111)ind = array([1,2.5, 4, 5.5, 7, 8.5])width = 1ax.bar(ind, [r1p, r2p, r3p, r4p, r5p, r100p], width=width)#title('Mean Number of Recruits for Team Starters and Team Followers')title("Hearing about the contest from Langley Castle directly greatly increases the likelihood of being a team starter")ylabel('p(Being a team starter)')xlabel("Relationship with the source from which heard about Langley Challenge")ax.set_xticks(ind+.5*width)xtickNames = ax.set_xticklabels( ('Friend', 'Family Member', 'Your Organization', 'Langley Castle', 'Media','Other') )plt.setp(xtickNames, rotation=45, fontsize=8)#xlim(ind[0]-.5*width, ind[1]+1.5*width)savefig("figure%i.png"%z, dpi=300, bbox_inches='tight')z+=1from scipy.stats import chisquarechisquare([len(r1),len(r2),len(r3),len(r4),len(r5),len(r100)])
# Out:
# (391.19095477386941, 2.3479658538993881e-82)

# %%
print "For Team Starters..."r1 = asarray([q for q in session.query(db.LangleyParticipant).\              filter_by(Relationship_with_Parent=1).\              filter_by(Has_Parent=False).\              values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()r2 = asarray([q for q in session.query(db.LangleyParticipant).\              filter_by(Relationship_with_Parent=2).\              filter_by(Has_Parent=False).\              values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()r3 = asarray([q for q in session.query(db.LangleyParticipant).\              filter_by(Relationship_with_Parent=3).\              filter_by(Has_Parent=False).\              values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()r4 = asarray([q for q in session.query(db.LangleyParticipant).\              filter_by(Relationship_with_Parent=4).\              filter_by(Has_Parent=False).\              values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()r5 = asarray([q for q in session.query(db.LangleyParticipant).\              filter_by(Relationship_with_Parent=5).\              filter_by(Has_Parent=False).\              values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()r100 = asarray([q for q in session.query(db.LangleyParticipant).\              filter_by(Relationship_with_Parent=100).\              filter_by(Has_Parent=False).\              values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()#plt.setp(xtickNames, rotation=45, fontsize=8)from scipy.stats import kruskalprint "Effect of Relationship with Person They Heard from: %.2f"%kruskal(r1, r2, r3, r4, r5, r100)[1]female = asarray([q for q in session.query(db.LangleyParticipant).\              filter_by(Gender='female').\              filter_by(Has_Parent=False).\              values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()male = asarray([q for q in session.query(db.LangleyParticipant).\              filter_by(Gender='male').\              filter_by(Has_Parent=False).\              values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()print "Effect of Gender: %.2f"%kruskal(male, female)[1]a1 = asarray([q for q in session.query(db.LangleyParticipant).\              filter_by(Age=1).\              filter_by(Has_Parent=False).\              values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()a2 = asarray([q for q in session.query(db.LangleyParticipant).\              filter_by(Age=2).\              filter_by(Has_Parent=False).\              values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()a3 = asarray([q for q in session.query(db.LangleyParticipant).\              filter_by(Age=3).\              filter_by(Has_Parent=False).\              values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()a4 = asarray([q for q in session.query(db.LangleyParticipant).\              filter_by(Age=4).\              filter_by(Has_Parent=False).\              values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()print "Effect of Age: %.2f"%kruskal(a1,a2,a3,a4)[1]h1 = asarray([q for q in session.query(db.LangleyParticipant).\              filter_by(Heard_Through_Medium=1).\              filter_by(Has_Parent=False).\              values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()h2 = asarray([q for q in session.query(db.LangleyParticipant).\              filter_by(Heard_Through_Medium=2).\              filter_by(Has_Parent=False).\              values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()h3 = asarray([q for q in session.query(db.LangleyParticipant).\              filter_by(Heard_Through_Medium=3).\              filter_by(Has_Parent=False).\              values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()h4 = asarray([q for q in session.query(db.LangleyParticipant).\              filter_by(Heard_Through_Medium=4).\              filter_by(Has_Parent=False).\              values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()h5 = asarray([q for q in session.query(db.LangleyParticipant).\              filter_by(Heard_Through_Medium=5).\              filter_by(Has_Parent=False).\              values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()h6 = asarray([q for q in session.query(db.LangleyParticipant).\              filter_by(Heard_Through_Medium=6).\              filter_by(Has_Parent=False).\              values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()h7 = asarray([q for q in session.query(db.LangleyParticipant).\              filter_by(Heard_Through_Medium=7).\              filter_by(Has_Parent=False).\              values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()h8 = asarray([q for q in session.query(db.LangleyParticipant).\              filter_by(Heard_Through_Medium=8).\              filter_by(Has_Parent=False).\              values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()h9 = asarray([q for q in session.query(db.LangleyParticipant).\              filter_by(Heard_Through_Medium=9).\              filter_by(Has_Parent=False).\              values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()h10 = asarray([q for q in session.query(db.LangleyParticipant).\              filter_by(Heard_Through_Medium=10).\              filter_by(Has_Parent=False).\              values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()h100 = asarray([q for q in session.query(db.LangleyParticipant).\              filter_by(Heard_Through_Medium=100).\              filter_by(Has_Parent=False).\              values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()print "Effect of Medium: %.2f"%kruskal(h1,h2,h3,h4,h5,h6,h7,h8,h9,h10,h100)[1]
# Out:
# For Team Starters...Effect of Relationship with Person They Heard from: 0.10Effect of Gender: 0.87Effect of Age: 0.18Effect of Medium: 0.93

# %%
join_times_team_starter = asarray([q for q in session.query(db.LangleyParticipant).filter_by(Has_Parent=False).values(getattr(db.LangleyParticipant, 'Join_Time'))]).flatten()number_of_children_team_starter = asarray([q for q in session.query(db.LangleyParticipant).filter_by(Has_Parent=False).values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()

# %%
join_times = asarray([q for q in session.query(db.LangleyParticipant).values(getattr(db.LangleyParticipant, 'Join_Time'))]).flatten()number_of_children = asarray([q for q in session.query(db.LangleyParticipant).values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()time_range = max(join_times)-min(join_times)day_range = time_range.days

# %%
challenge_start_date = date2num(datetime.datetime(2011,7,2))challenge_end_date = date2num(datetime.datetime(2011,7,4))

# %%
import matplotlib.dates as mdatesmonths   = mdates.MonthLocator()monthsFmt = mdates.DateFormatter('%m')fig = plt.figure()ax = fig.add_subplot(111)x = hist(date2num(join_times), bins=day_range)ax.xaxis.set_major_locator(mdates.MonthLocator(bymonth=range(6,10)))ax.set_xticklabels(['June', 'July', 'August', 'September'])#ax.xaxis.set_major_formatter(monthsFmt)handles = {}handles["Challenge Start"] = ax.plot((challenge_start_date, challenge_start_date), ylim(), label="Challenge Start")handles["Challenge End"] = ax.plot((challenge_end_date, challenge_end_date), ylim(), label="Challenge End")handles, labels = ax.get_legend_handles_labels()ax.legend(handles[::-1], labels[::-1], loc=1)title("Timeline of Sign Ups")ylabel('Number of Sign Ups')xlabel('Sign Up Day')savefig("figure%i.png"%z, dpi=300, bbox_inches='tight')z+=1m, b, r, p, stderr = linregress(date2num(join_times), number_of_children)fig = plt.figure()ax = fig.add_subplot(111)handles = {}handles["All"] = ax.scatter(date2num(join_times), number_of_children, label='Followers')handles["Team Starter"] = ax.scatter(date2num(join_times_team_starter), number_of_children_team_starter, c='r', label='Team Starters')ax.xaxis.set_major_locator(mdates.MonthLocator(bymonth=range(6,10)))ax.set_xticklabels(['June', 'July', 'August', 'September'])#ax.xaxis.set_major_formatter(monthsFmt)title("Number of Shares by Sign Up Date")ylabel('Number of Shares')xlabel('Sign Up Day')x = arange(xlim()[0], xlim()[1])y = m*x+bax.plot(x,y)handles["Challenge Start"] = ax.plot((challenge_start_date, challenge_start_date), ylim(), label="Challenge Start")handles["Challenge End"] = ax.plot((challenge_end_date, challenge_end_date), ylim(), label="Challenge End")handles, labels = ax.get_legend_handles_labels()ax.legend(handles[::-1], labels[::-1], loc=1)ylim(-1, 350)text(.1, .5, "y = %.2f*x+%.1f, R^2=%.2f, p=%.3f"%(m,b,r**2, p), transform = ax.transAxes)savefig("figure%i.png"%z, dpi=300, bbox_inches='tight')z+=1valid_cases = (number_of_children<40)*(join_times<datetime.datetime(2011,7,4))valid_cases_team_starter = (number_of_children_team_starter<40)*(join_times_team_starter<datetime.datetime(2011,7,4))m, b, r, p, stderr = linregress(date2num(join_times[valid_cases]), number_of_children[valid_cases])fig = plt.figure()ax = fig.add_subplot(111)handles = {}handles["All"] = ax.scatter(date2num(join_times[valid_cases]), number_of_children[valid_cases], label='Followers')handles["Team Starter"] = ax.scatter(date2num(join_times_team_starter[valid_cases_team_starter]), number_of_children_team_starter[valid_cases_team_starter], c='r', label='Team Starters')ax.xaxis.set_major_locator(mdates.MonthLocator(bymonth=range(6,10)))ax.set_xticklabels(['June', 'July', 'August', 'September'])#ax.xaxis.set_major_formatter(monthsFmt)title("Number of Shares by Sign Up (Excluding Outliers and Latecomers)")ylabel('Number of Shares')xlabel('Sign Up Day')x = arange(xlim()[0], xlim()[1])y = m*x+bax.plot(x,y)ylim(-1, 40)handles["Challenge Start"] = ax.plot((challenge_start_date, challenge_start_date), ylim(), label="Challenge Start")handles["Challenge End"] = ax.plot((challenge_end_date, challenge_end_date), ylim(), label="Challenge End")handles, labels = ax.get_legend_handles_labels()ax.legend(handles[::-1], labels[::-1], loc=2)text(.1, .5, "y = %.2f*x+%.1f, R^2=%.2f, p=%.3f"%(m,b,r**2, p), transform = ax.transAxes)savefig("figure%i.png"%z, dpi=300, bbox_inches='tight')z+=1

# %%
def starter_join(G):    d = datetime.datetime(2013,7,2)    for i in G.node:        d = min(d,G.node[i]['join_time'])    return d

# %% [markdown]
# ###Simply being early to sign up in the team doesn't lead to more shares

# %%
time_diff = []sigmas = []for i in range(len(C)):        if networkx.number_of_nodes(C[i])>1:        sj = starter_join(C[i])        for j in C[i].nodes():            c = C[i].node[j]['join_time']-sj            time_diff.append(c.days * 86400 + c.seconds)            #print time_diff[-1]            #print C[i].node[j]['join_time']-sj            sigmas.append(C[i].node[j]['sigma'])            fig = plt.figure()ax = fig.add_subplot(111)ax.scatter(time_diff, sigmas)ylim(-10, ylim()[1])xlim(-100000, xlim()[1])ylabel("Number of Shares")xlabel("Time Between A Recruit Registering and Their Team Starter Registering (seconds)")title("Simply being early to sign up in the team doesn't lead to more shares")m, b, r, p, stderr = linregress(time_diff, sigmas)x = arange(xlim()[0], xlim()[1])y = m*x+bax.plot(x,y)text(.1, .5, "y = %f*x+%.1f, R^2=%.2f, p=%.3f"%(m,b,r**2, p), transform = ax.transAxes)savefig("figure%i.png"%z, dpi=300, bbox_inches='tight')z+=1

# %% [markdown]
# ###Age demographics affects propensity to share

# %%
sigmas = asarray([q for q in session.query(db.LangleyParticipant).values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()sigma_same_age = asarray([q for q in session.query(db.LangleyParticipant).filter_by(Same_Age_as_Parent=True).values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()sigma_different_age = asarray([q for q in session.query(db.LangleyParticipant).filter_by(Same_Age_as_Parent=False).values(getattr(db.LangleyParticipant, 'Number_of_Children'))]).flatten()Stds = (std(sigma_starter), std(sigma_follower))fig = plt.figure()print len(sigma_same_age)+len(sigma_different_age)ax = fig.add_subplot(111)ind = array([1, 2.5])width = 1ax.bar(ind, [mean(sigma_same_age>0), mean(sigma_different_age>0)], width=width)ylim(0,1)#title('Mean Number of Recruits for Team Starters and Team Followers')title("Being Same Age as Recruiter Increases Sharing Probability")ylabel('Probability of Sharing')ax.set_xticks(ind+.5*width)plt.setp(ax, xticklabels=["Same Age", "Different Age"])#plt.setp(xtickNames, rotation=45, fontsize=8)xlim(ind[0]-.5*width, ind[1]+1.5*width)savefig("figure%i.png"%z, dpi=300, bbox_inches='tight')z+=1fig = plt.figure()ax = fig.add_subplot(111)ax.bar([1,2], [mean(sigma_same_age), mean(sigma_different_age)], yerr=Stds)ylim(0,5)title("Being Same Age as Recruiter Increases Total Sharing (Barely)")ylabel('Mean Number of Shares')savefig("figure%i.png"%z, dpi=300, bbox_inches='tight')z+=1fig = plt.figure()ax = fig.add_subplot(111)ind = array([1,2.5])width = 1ax.bar(ind, [len(sigma_same_age), len(sigma_different_age)])from scipy.stats import chisquareprint chisquare([len(sigma_same_age), len(sigma_different_age)])#from scipy.stats.stats import pearsonr#print pearsonr([len(ri_same_age), len(ri_different_age)], [median(ri_same_age), median(ri_different_age)])#fig = plt.figure()#ax = fig.add_subplot(111)#ys, xs = powerlaw.cumulative_distribution_function(sigma_same_age, survival=True)#yf, xf = powerlaw.cumulative_distribution_function(sigma_different_age, survival=True)#y, x = powerlaw.cumulative_distribution_function(sigmas, survival=True)#handles = {}#handles["All"] = ax.plot(x, y, label="All", linewidth=4, color='k')#handles["Team Starters"] = ax.plot(xs, ys, label="Team Starters")#handles["Followers"] = ax.plot(xf, yf, label="Followers")#ax.set_xscale("log")#ax.set_yscale("log")#xlabel("Number of Recruits")#ylabel("p(Recruits>x)")#handles, labels = ax.get_legend_handles_labels()#ax.legend(handles[::-1], labels[::-1], loc=1)
# Out:
# 941(122.12646121147715, 2.165833098267911e-28)

# %% [markdown]
# Registration Intervals==========The registration interval is the time between when an individual registered and when their recruiter registered. This may reflect response times to invitations (a decision of the recruited) or the speed of making invitations (a decision of the recruiter) or both----------

# %% [markdown]
# ####Registration intervals are shorter when the recruiter and the recruited are the same age

# %%
ri_same_age = asarray([q for q in session.query(db.LangleyParticipant).filter_by(Same_Age_as_Parent=True).filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()ri_different_age= asarray([q for q in session.query(db.LangleyParticipant).filter_by(Same_Age_as_Parent=False).filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()print len(ri_same_age)+len(ri_different_age)fig = plt.figure()ax = fig.add_subplot(111)ax.boxplot([ri_same_age, ri_different_age], notch=1)title("Registration Interval is Shorter When the Recruiter and Recruited are the Same Age")ylabel('Recruiter-Recruited Registration Inverval(seconds)')plt.setp(ax, xticklabels=["Same Age", "Different Age"])#plt.setp(xtickNames, rotation=45, fontsize=8)savefig("figure%i.png"%z, dpi=300, bbox_inches='tight')z+=1fig = plt.figure()ax = fig.add_subplot(111)ind = array([1,2.5])width = 1ax.bar(ind, [len(ri_same_age), len(ri_different_age)])from scipy.stats import chisquareprint chisquare([len(ri_same_age), len(ri_different_age)])#from scipy.stats.stats import pearsonr#print pearsonr([len(ri_same_age), len(ri_different_age)], [median(ri_same_age), median(ri_different_age)])print "%.3f"%odds_of_small_ris(ri_same_age)
# Out:
# 941(122.12646121147715, 2.165833098267911e-28)
# 0.000

# %% [markdown]
# ###Quickest registration intervals are when the recruiter is female, with no difference between the recruited genders. When the recruiter is male, both recruited genders respond slower, but males slow down more.

# %%
ri_male_male = asarray([q for q in session.query(db.LangleyParticipant).\                        filter_by(Gender='male').\                        filter_by(Parent_Gender='male').\                        filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).\                        values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()ri_male_female = asarray([q for q in session.query(db.LangleyParticipant).\                        filter_by(Gender='male').\                        filter_by(Parent_Gender='female').\                        filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).\                        values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()ri_female_female = asarray([q for q in session.query(db.LangleyParticipant).\                        filter_by(Gender='female').\                        filter_by(Parent_Gender='female').\                        filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).\                        values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()ri_female_male = asarray([q for q in session.query(db.LangleyParticipant).\                        filter_by(Gender='female').\                        filter_by(Parent_Gender='male').\                        filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).\                        values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()#fig = plt.figure(figsize=(16, 8))fig = plt.figure(figsize=(4.6,2.84295635))ax = fig.add_subplot(121)vals = asarray([ri_male_male, ri_female_male, ri_male_female, ri_female_female])vals = vals/(60*60.0*24.0)bp = ax.boxplot(vals, notch=1)#title("Registration Interval is Shorter for Females")ylabel('Mobilization Speed(Days)')#plt.setp(ax, xticklabels=["Male\nfrom Male", "Female\nfrom Male", "Male\nfrom Female", "Female\nfrom Female"])ylim(0, ylim()[1])xtickNames = plt.setp(ax, xticklabels=["Male->\nMale", "Male->\nFemale", "Female->\nMale","Female->\nFemale"])plt.setp(xtickNames, rotation=45, fontsize=8)from scipy.stats import kruskalp_krusks = zeros(5)p_krusks[0]=kruskal(ri_male_male, ri_female_male)[1]p_krusks[1]=kruskal(ri_male_female, ri_female_female)[1]p_krusks[2]=kruskal(ri_female_male, ri_male_female)[1]p_krusks[3]=kruskal(ri_female_male, ri_female_female)[1]p_krusks[4]=kruskal(ri_male_male, ri_male_female)[1]from rpy2.robjects.packages import importrfrom rpy2.robjects.vectors import FloatVectorstats = importr('stats')p_krusks = asarray(stats.p_adjust(FloatVector(p_krusks), method = 'holm'))setp(bp['boxes'][0], color='blue')setp(bp['boxes'][1], color='green')setp(bp['boxes'][2:4], color='black')#plt.setp(ax.get_xticklabels(), visible=False)ax = fig.add_subplot(122, sharex=ax)ylabel("Count of Relationship Type in Contest")width = .75ind = arange(4)+(1-width/2)xlim(.5, 4.5)freqs = []medians = []for i in vals:    freqs.append(len(i))    medians.append(median(i))freqs = asarray(freqs)medians = asarray(medians)    ax.bar(ind, freqs, width=width)subplots_adjust(wspace=0.5)plt.xticks(ind+.5*width)#plt.setp(ax, xticklabels=["Male", "Female", "Male", "Female", "Male", "Female", "Male", "Female"])#plt.setp(ax, xticklabels=["Male\nfrom\nMale", "Female\nfrom\nMale", "Male\nfrom\nFemale", "Female\nfrom\nFemale", "Male\nfrom\nMale", "Female\nfrom\nMale", "Male\nfrom\nFemale", "Female\nfrom\nFemale"])#plt.setp(ax, xticklabels=["Male-Male", "Female-Male", "Male-Female", "Female-Female", "Male-Male", "Female-Male", "Male-Female", "Female-Female"])xtickNames = plt.setp(ax, xticklabels=["Male->\nMale", "Male->\nFemale", "Female->\nMale","Female->\nFemale"])plt.setp(xtickNames, rotation=45, fontsize=8)xlabel("Broadcaster-Receiver Relationship Type ")plt.yticks(arange(0,400, 100),arange(0,400, 100))#ax = fig.add_subplot(313)#ylabel('Median Sharing Speed (Days)')#xlabel("Count of Relationship Type in Contest")#ax.scatter(freqs, medians)#m, b, r, p, stderr = linregress(freqs, medians)#print m#print b#xlim(0, xlim()[1])#x = asarray(xlim())#y = m*x+b#ax.plot(x,y)#ylim(0, ylim()[1])#text(.1, .9, "y = %.2fx+%.1f, R$^2$=%.2f, p=%.3f"%(m,b,r**2, p), transform = ax.transAxes)savefig("figure%i.png"%z, dpi=300, bbox_inches='tight')z+=1

# %%
ri_male_male_same = asarray([q for q in session.query(db.LangleyParticipant).\                        filter_by(Gender='male').\                        filter_by(Parent_Gender='male').\                        filter_by(Same_City_as_Parent=True).\                        filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).\                        values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()ri_male_male_diff = asarray([q for q in session.query(db.LangleyParticipant).\                        filter_by(Gender='male').\                        filter_by(Parent_Gender='male').\                        filter_by(Same_City_as_Parent=False).\                        filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).\                        values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()ri_male_female_same = asarray([q for q in session.query(db.LangleyParticipant).\                        filter_by(Gender='male').\                        filter_by(Parent_Gender='female').\                        filter_by(Same_City_as_Parent=True).\                        filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).\                        values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()ri_male_female_diff = asarray([q for q in session.query(db.LangleyParticipant).\                        filter_by(Gender='male').\                        filter_by(Parent_Gender='female').\                        filter_by(Same_City_as_Parent=False).\                        filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).\                        values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()ri_female_male_same = asarray([q for q in session.query(db.LangleyParticipant).\                        filter_by(Gender='female').\                        filter_by(Parent_Gender='male').\                        filter_by(Same_City_as_Parent=True).\                        filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).\                        values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()ri_female_male_diff = asarray([q for q in session.query(db.LangleyParticipant).\                        filter_by(Gender='female').\                        filter_by(Parent_Gender='male').\                        filter_by(Same_City_as_Parent=False).\                        filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).\                        values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()ri_female_female_same = asarray([q for q in session.query(db.LangleyParticipant).\                        filter_by(Gender='female').\                        filter_by(Parent_Gender='female').\                        filter_by(Same_City_as_Parent=True).\                        filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).\                        values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()ri_female_female_diff = asarray([q for q in session.query(db.LangleyParticipant).\                        filter_by(Gender='female').\                        filter_by(Parent_Gender='female').\                        filter_by(Same_City_as_Parent=False).\                        filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).\                        values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()fig = plt.figure(figsize=(8, 16))fig.suptitle("Mobilization Speed Across a Relationship is Determined by the Frequency of that Relationship Type")ax = fig.add_subplot(3,1,1)vals = [ri_male_male_diff, ri_female_male_diff, ri_male_female_diff, ri_female_female_diff, ri_male_male_same, ri_female_male_same, ri_male_female_same, ri_female_female_same]vals = asarray(vals)/(60*60.0*24)bp = ax.boxplot(vals, notch=1)ylabel('Mobilization Speed (Days)')#xtickNames=plt.setp(ax, xticklabels=["Male\nfrom Male", "Female\nfrom Male", "Male\nfrom Female", "Female\nfrom Female", "Male\nfrom Male", "Female\nfrom Male", "Male\nfrom Female", "Female\nfrom Female"])#plt.setp(xtickNames, rotation=45, fontsize=8)ylim(0, ylim()[1])from scipy.stats import kruskalp_krusks = []p_krusks.append(kruskal(ri_male_male_same, ri_female_male_same)[1])p_krusks.append(kruskal(ri_male_female_same, ri_female_female_same)[1])p_krusks.append(kruskal(ri_female_male_same, ri_male_female_same)[1])p_krusks.append(kruskal(ri_female_male_same, ri_female_female_same)[1])p_krusks.append(kruskal(ri_male_male_same, ri_male_female_same)[1])p_krusks.append(kruskal(ri_male_male_diff, ri_female_male_diff)[1])p_krusks.append(kruskal(ri_male_female_diff, ri_female_female_diff)[1])p_krusks.append(kruskal(ri_female_male_diff, ri_male_female_diff)[1])p_krusks.append(kruskal(ri_female_male_diff, ri_female_female_diff)[1])p_krusks.append(kruskal(ri_male_male_diff, ri_male_female_diff)[1])p_krusks.append(kruskal(ri_female_female_same, ri_female_female_diff)[1])from rpy2.robjects.packages import importrfrom rpy2.robjects.vectors import FloatVectorstats = importr('stats')p_krusks = asarray(stats.p_adjust(FloatVector(p_krusks), method = 'holm'))#print p_krusksprint shape(bp['boxes'])setp(bp['boxes'][0], color='blue')setp(bp['boxes'][1], color='green')setp(bp['boxes'][2:4], color='black')setp(bp['boxes'][4:], color='red')#ax.get_xaxis().set_ticks([])plt.setp(ax.get_xticklabels(), visible=False)ax = fig.add_subplot(312, sharex=ax)ylabel("Count of Relationship Type in Contest")ind = array([1,2.5, 4, 5.5, 7, 8.5, 10, 11.5])width = .75ind = arange(8)+(1-width/2)xlim(.5, 8.5)ax.bar(ind, [len(ri_male_male_diff), len(ri_female_male_diff), len(ri_male_female_diff), len(ri_female_female_diff), len(ri_male_male_same), len(ri_female_male_same), len(ri_male_female_same), len(ri_female_female_same)], width=width)plt.xticks(ind+.5*width)#plt.setp(ax, xticklabels=["Male", "Female", "Male", "Female", "Male", "Female", "Male", "Female"])#plt.setp(ax, xticklabels=["Male\nfrom\nMale", "Female\nfrom\nMale", "Male\nfrom\nFemale", "Female\nfrom\nFemale", "Male\nfrom\nMale", "Female\nfrom\nMale", "Male\nfrom\nFemale", "Female\nfrom\nFemale"])#plt.setp(ax, xticklabels=["Male-Male", "Female-Male", "Male-Female", "Female-Female", "Male-Male", "Female-Male", "Male-Female", "Female-Female"])plt.setp(ax, xticklabels=["Male->\nMale", "Male->\nFemale", "Female->\nMale","Female->\nFemale", "Male->\nMale", "Male->\nFemale", "Female->\nMale","Female->\nFemale"])xlabel("\nDifferent City                                                   Same City\nBroadcaster-Receiver Relationship Type ")#ax.text(-.2,-.03, 'Reciever gender:', transform = ax.transAxes)#ax.text(-.2,-.06, 'Broadcaster gender:', transform = ax.transAxes)#ax.text(-.2,-.095, 'Location:', transform = ax.transAxes)#xtickNames=plt.setp(xtickNames, rotation=45, fontsize=8)#from scipy.stats import chisquare#expected = sum([len(ri_male_male_same), len(ri_female_male_same), len(ri_male_female_same), len(ri_female_female_same)])/4#print chisquare([len(ri_male_male_same), len(ri_female_male_same), len(ri_male_female_same), len(ri_female_female_same)])#print chisquare([len(ri_male_male_diff), len(ri_female_male_diff), len(ri_male_female_diff), len(ri_female_female_diff)])#from scipy.stats.stats import pearsonr#print pearsonr([len(ri_male_male_same), len(ri_female_male_same), len(ri_male_female_same), len(ri_female_female_same), len(ri_male_male_diff), len(ri_female_male_diff), len(ri_male_female_diff), len(ri_female_female_diff)], [median(ri_male_male_same), median(ri_female_male_same), median(ri_male_female_same), median(ri_female_female_same), median(ri_male_male_diff), median(ri_female_male_diff), median(ri_male_female_diff), median(ri_female_female_diff)])#print pearsonr([len(ri_male_male_same), len(ri_female_male_same), len(ri_male_female_same), len(ri_female_female_same), len(ri_male_male_diff), len(ri_female_male_diff), len(ri_male_female_diff), len(ri_female_female_diff)], [mean(ri_male_male_same), mean(ri_female_male_same), mean(ri_male_female_same), mean(ri_female_female_same), mean(ri_male_male_diff), mean(ri_female_male_diff), mean(ri_male_female_diff), mean(ri_female_female_diff)])subplots_adjust(hspace=0.1)ax = fig.add_subplot(313)subplots_adjust(hspace=0.3)ylabel('Median Mobilization Speed (Days)')xlabel("Count of Relationship Type in Contest")freqs = [len(ri_male_male_same), len(ri_female_male_same), len(ri_male_female_same), len(ri_female_female_same), len(ri_male_male_diff), len(ri_female_male_diff), len(ri_male_female_diff), len(ri_female_female_diff)]#freqs = asarray(freqs)/float(len(ris))medians = [median(ri_male_male_same), median(ri_female_male_same), median(ri_male_female_same), median(ri_female_female_same), median(ri_male_male_diff), median(ri_female_male_diff), median(ri_male_female_diff), median(ri_female_female_diff)]medians = asarray(medians)/(60*60.0*24)ax.scatter(freqs, medians)m, b, r, p, stderr = linregress(freqs, medians)print mprint bxlim(0, xlim()[1])x = asarray(xlim())y = m*x+bax.plot(x,y)ylim(0, ylim()[1])text(.1, .9, u"y = %.2fx+%.1f, R\u00B2 = %.2f, p=%.3f"%(m,b,r**2, p), transform = ax.transAxes)#text(50,6, u"R\u00B2 = %.2f"%(r**2), fontsize=30)savefig("figure%i.png"%z, dpi=300, bbox_inches='tight')z+=1
# Out:
# (8,)0.025394896402
# -0.779472657906

# %% [markdown]
# ###Registration Interval is Shorter for Females

# %%
ri_male = asarray([q for q in session.query(db.LangleyParticipant).filter_by(Gender='male').filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()ri_female= asarray([q for q in session.query(db.LangleyParticipant).filter_by(Gender='female').filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()Stds = (std(ri_male), std(ri_female))fig = plt.figure()ax = fig.add_subplot(111)ax.boxplot([ri_male, ri_female], notch=1)title("Registration Interval is Shorter for Females")ylabel('Recruiter-Recruited Registration Inverval(seconds)')plt.setp(ax, xticklabels=["Male", "Female"])#plt.setp(xtickNames, rotation=45, fontsize=8)
# Out:
# [&lt;matplotlib.text.Text at 0x11dd2150&gt;, &lt;matplotlib.text.Text at 0x148bae50&gt;]

# %% [markdown]
# ###Registration Interval is Shorter for When the Recruiter and Recruited Are the Same Gender

# %%
ri_same = asarray([q for q in session.query(db.LangleyParticipant).filter_by(Same_Gender_as_Parent=True).filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()ri_different= asarray([q for q in session.query(db.LangleyParticipant).filter_by(Same_Gender_as_Parent=False).filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()Stds = (std(ri_same ), std(ri_different))fig = plt.figure()ax = fig.add_subplot(111)ax.boxplot([ri_same, ri_different], notch=1)title("Registration Interval is Shorter for When the Recruiter and Recruited Are the Same Gender")ylabel('Recruiter-Recruited Registration Inverval(seconds)')plt.setp(ax, xticklabels=["Same Gender", "Different Gender"])#plt.setp(xtickNames, rotation=45, fontsize=8)
# Out:
# [&lt;matplotlib.text.Text at 0x17badbd0&gt;, &lt;matplotlib.text.Text at 0x142a9310&gt;]

# %%
ri_same_medium = asarray([q for q in session.query(db.LangleyParticipant).filter_by(Heard_Through_Same_Medium_as_Parent=True).filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()ri_different_medium= asarray([q for q in session.query(db.LangleyParticipant).filter_by(Heard_Through_Same_Medium_as_Parent=False).filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()fig = plt.figure()ax = fig.add_subplot(111)ax.boxplot([ri_same_medium, ri_different_medium], notch=1)title("Registration Interval is Shorter When the Recruiter and Recruited Heard About the Challenge through the Same Medium")ylabel('Recruiter-Recruited Registration Inverval(seconds)')plt.setp(ax, xticklabels=["Same Medium", "Different Medium"])#plt.setp(xtickNames, rotation=45, fontsize=8)savefig("figure%i.png"%z, dpi=300, bbox_inches='tight')z+=1fig = plt.figure()ax = fig.add_subplot(111)ind = array([1,2.5])width = 1ax.bar(ind, [len(ri_same_medium), len(ri_different_medium)])from scipy.stats import chisquareprint chisquare([len(ri_same_medium), len(ri_different_medium)])#from scipy.stats.stats import pearsonr#print pearsonr([len(ri_same_age), len(ri_different_age)], [median(ri_same_age), median(ri_different_age)])print "%.3f"%odds_of_small_ris(ri_same_medium)
# Out:
# (304.17109458023378, 4.0649094745892134e-68)0.000

# %%
ri_same_relationship = asarray([q for q in session.query(db.LangleyParticipant).filter_by(Same_Relationship_to_Parent_as_They_Had_to_Their_Parent=True).filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()ri_different_relationship= asarray([q for q in session.query(db.LangleyParticipant).filter_by(Same_Relationship_to_Parent_as_They_Had_to_Their_Parent=False).filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()fig = plt.figure()ax = fig.add_subplot(111)ax.boxplot([ri_same_relationship, ri_different_relationship], notch=1)title("Registration Interval is Shorter for When the Recruiter and Recruited Have the Same Relationship as the Recruiter and THEIR Recruiter")ylabel('Recruiter-Recruited Registration Inverval(seconds)')plt.setp(ax, xticklabels=["Same Relationship", "Different Relationship"])#plt.setp(xtickNames, rotation=45, fontsize=8)savefig("figure%i.png"%z, dpi=300, bbox_inches='tight')z+=1fig = plt.figure()ax = fig.add_subplot(111)ind = array([1,2.5])width = 1ax.bar(ind, [len(ri_same_relationship), len(ri_different_relationship)])from scipy.stats import chisquareprint chisquare([len(ri_same_relationship), len(ri_different_relationship)])#from scipy.stats.stats import pearsonr#print pearsonr([len(ri_same_age), len(ri_different_age)], [median(ri_same_age), median(ri_different_age)])print "%.3f"%odds_of_small_ris(ri_same_relationship)
# Out:
# (546.32199787460149, 7.9452921480415209e-121)0.000

# %% [markdown]
# The Effects of Distance====================

# %% [markdown]
# Most shares are local, transatlantic, or UK-India---------------------

# %%
fig = plt.figure()ax = fig.add_subplot(111)ax.hist(ds, bins=100)title("Most shares are local, transatlantic, or UK-India")xlabel('Recruiter-Recruited Distance(km)')ylabel('p(Distance)')handles = {}handles["Average"] = ax.plot((6838.055,6838.055),ylim(), label="Typical UK-US Distance")handles["West Coast"] = ax.plot((7235.593,7235.593), ylim(), label="Typical UK-US West Coast Distance")handles["India"] = ax.plot((7671.233,7671.233), ylim(), label="Typical UK-India Distance")xlabel("Distance from Recruiter")ylabel("Count of Distances")handles, labels = ax.get_legend_handles_labels()ax.legend(handles[::-1], labels[::-1], loc=1)savefig("figure%i.png"%z, dpi=300, bbox_inches='tight')z+=1

# %%
ri_same_city = asarray([q for q in session.query(db.LangleyParticipant).\                   filter_by(Same_City_as_Parent=True).\                   filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).\                   values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()ri_same_country_different_city = asarray([q for q in session.query(db.LangleyParticipant).\                   filter_by(Same_City_as_Parent=False).\                   filter_by(Same_Country_as_Parent=True).\                   filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).\                   values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()ri_different = asarray([q for q in session.query(db.LangleyParticipant).\                   filter_by(Same_City_as_Parent=False).\                   filter_by(Same_Country_as_Parent=False).\                   filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).\                   values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()vals = asarray([ri_different, ri_same_country_different_city, ri_same_city])vals = vals/(60*60.0*24.0)fig = plt.figure(figsize=(4.6,2.84295635))#fig = plt.figure(figsize=(2.3,1.42147817))ax = fig.add_subplot(121)bp = ax.boxplot(vals, notch=1)#suptitle("Social Mobilization is Faster When the Recruiter and Recruited Are in the Same City")ylabel('Mobilization Speed (Days)')xtickNames = plt.setp(ax, xticklabels=[ "Different Country", "Same Country,\nDifferent City", "Same City"])#, rotation=90, fontsize=8)plt.setp(xtickNames, rotation=90, fontsize=8)ylim(0, ylim()[1])setp(bp['boxes'][0:2], color='blue')setp(bp['boxes'][2], color='red')ax = fig.add_subplot(122)#ind = array([1,2.5,4])#width = 1width = .75ind = arange(3)+(1-width/2)#xlim(.5, 8.5)ax.bar(ind, [len(ri_different),len(ri_same_country_different_city),len(ri_same_city)])plt.yticks(arange(0,500, 100),arange(0,500, 100))plt.xticks(ind+.5*width)xtickNames = plt.setp(ax, xticklabels=[ "Different Country", "Same Country,\nDifferent City", "Same City", ])plt.setp(ax.get_xticklabels(), rotation=90, fontsize=8)ylabel("Count of Relationship Type")fig.subplots_adjust(wspace=0.5)savefig("figure%i.png"%z, dpi=300, bbox_inches='tight')z+=1from scipy.stats import kruskalp_krusks = []p_krusks.append(kruskal(ri_same_city, ri_same_country_different_city)[1])p_krusks.append(kruskal(ri_same_country_different_city, ri_different)[1])p_krusks.append(kruskal(ri_same_city, ri_different)[1])from rpy2.robjects.packages import importrfrom rpy2.robjects.vectors import FloatVectorstats = importr('stats')p_krusks = asarray(stats.p_adjust(FloatVector(p_krusks), method = 'holm'))print p_krusksfrom scipy.stats import chisquareprint chisquare([len(ri_same_city), len(ri_same_country_different_city), len(ri_different)])from scipy.stats.stats import pearsonrprint pearsonr([len(ri_same_city), len(ri_same_country_different_city), len(ri_different)], [median(ri_same_city), median(ri_same_country_different_city), median(ri_different)])
# Out:
# [  6.97586485e-23   5.81656731e-01   6.44031888e-29](153.06269925611051, 5.7923815817611356e-34)(0.93977248510861755, 0.22207351891255314)

# %%
z
# Out:
# 61

# %% [markdown]
# Registration Interval is Shorter for When the Recruiter and Recruited Are in the Same Country---------------

# %%
ri_same = asarray([q for q in session.query(db.LangleyParticipant).filter_by(Same_Country_as_Parent=True).filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()ri_different= asarray([q for q in session.query(db.LangleyParticipant).filter_by(Same_Country_as_Parent=False).filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()Stds = (std(ri_same ), std(ri_different))fig = plt.figure()ax = fig.add_subplot(111)ax.boxplot([ri_same, ri_different], notch=1)title("Registration Interval is Shorter for When the Recruiter and Recruited Are in the Same Country")ylabel('Recruiter-Recruited Registration Inverval(seconds)')plt.setp(ax, xticklabels=["Same Country", "Different Country"])#plt.setp(xtickNames, rotation=45, fontsize=8)
# Out:
# [&lt;matplotlib.text.Text at 0x11603250&gt;, &lt;matplotlib.text.Text at 0x11603910&gt;]

# %% [markdown]
# Registration Interval is Shorter for When the Recruiter and Recruited Are in the Same City-------------

# %%
ri_same = asarray([q for q in session.query(db.LangleyParticipant).filter_by(Same_City_as_Parent=True).filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()ri_different= asarray([q for q in session.query(db.LangleyParticipant).filter_by(Same_City_as_Parent=False).filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()Stds = (std(ri_same ), std(ri_different))fig = plt.figure()ax = fig.add_subplot(111)ax.boxplot([ri_same, ri_different], notch=1)title("Registration Interval is Shorter for When the Recruiter and Recruited Are in the Same City")ylabel('Recruiter-Recruited Registration Inverval(seconds)')plt.setp(ax, xticklabels=["Same City", "Different City"])#plt.setp(xtickNames, rotation=45, fontsize=8)ylim(0, ylim()[1])
# Out:
# (0, 2500000.0)

# %% [markdown]
# Rapid local registrations and longer international registrations do not generalize to an overall distance effect on registration time---------------------

# %%
fig = plt.figure()ax = fig.add_subplot(111)ax.scatter(ds, ris)title("Rapid local registrations and longer international registrations do not generalize to an overall distance effect on registration time")ylabel('Recruiter-Recruited Registration Inverval(seconds)')xlabel('Recruiter-Recruited Distance(km)')xlim(-1000,20000)ylim(-100000, ylim()[1])#m, b, r, p, stderr = linregress(ds, ris)#x = arange(xlim()[0], xlim()[1])#y = m*x+b#ax.plot(x,y)handles = {}handles["Average"] = ax.plot((6838.055,6838.055),ylim(), label="Typical UK-US Distance")handles["West Coast"] = ax.plot((7235.593,7235.593), ylim(), label="Typical UK-US West Coast Distance")handles["India"] = ax.plot((7671.233,7671.233), ylim(), label="Typical UK-India Distance")xlabel("Recruiter-Recruited Distance (km)")ylabel("Registration Interval (seconds)")handles, labels = ax.get_legend_handles_labels()ax.legend(handles[::-1], labels[::-1], loc=1)savefig("figure%i.png"%z, dpi=300, bbox_inches='tight')z+=1

# %%
ds_ris = asarray([q for q in session.query(db.LangleyParticipant)\               .filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None) \               .filter(db.LangleyParticipant.Distance_from_Parent!=None)\               .values(db.LangleyParticipant.Parent_Child_Registration_Interval_Corrected, \                       db.LangleyParticipant.Distance_from_Parent,\                       db.LangleyParticipant.Number_of_Children,\                       db.LangleyParticipant.Depth_in_Invite_Chain)])ds = ds_ris[:,1]ris = ds_ris[:,0]number_of_children = ds_ris[:,2]depths = ds_ris[:,3]

# %%
fig = plt.figure()ax = fig.add_subplot(111)ax.scatter(ds, number_of_children)title("No Effect of Distance on Number of Shares")ylabel('Number of Shares')xlabel('Recruiter-Recruited Distance(km)')xlim(-1000,20000)ylim(-1, ylim()[1])#m, b, r, p, stderr = linregress(ds, ris)#x = arange(xlim()[0], xlim()[1])#y = m*x+b#ax.plot(x,y)m, b, r, p, stderr = linregress(ds, number_of_children)x = arange(xlim()[0], xlim()[1])y = m*x+bax.plot(x,y)text(.1, .5, "y = %.2f*x+%.1f, R^2=%.2f, p=%.3f"%(m,b,r**2, p), transform = ax.transAxes)handles = {}handles["Average"] = ax.plot((6838.055,6838.055),ylim(), label="Typical UK-US Distance")handles["West Coast"] = ax.plot((7235.593,7235.593), ylim(), label="Typical UK-US West Coast Distance")handles["India"] = ax.plot((7671.233,7671.233), ylim(), label="Typical UK-India Distance")xlabel("Recruiter-Recruited Distance (km)")ylabel("Number of Shares")handles, labels = ax.get_legend_handles_labels()ax.legend(handles[::-1], labels[::-1], loc=1)savefig("figure%i.png"%z, dpi=300, bbox_inches='tight')z+=1

# %%
fig = plt.figure()ax = fig.add_subplot(111)ax.scatter(ris, number_of_children)title("No Effect of Registration Interval on Number of Shares")ylabel('Number of Shares')xlabel('Registraction Interval (s)')xlim(-100000, xlim()[1])ylim(-1, ylim()[1])#m, b, r, p, stderr = linregress(ds, ris)#x = arange(xlim()[0], xlim()[1])#y = m*x+b#ax.plot(x,y)m, b, r, p, stderr = linregress(ris, number_of_children)x = arange(xlim()[0], xlim()[1])y = m*x+bax.plot(x,y)text(.1, .5, "y = %.2f*x+%.1f, R^2=%.2f, p=%.3f"%(m,b,r**2, p), transform = ax.transAxes)xlabel("Registration Interval (seconds)")ylabel("Number of Shares")savefig("figure%i.png"%z, dpi=300, bbox_inches='tight')z+=1

# %%
hist(ris, bins=100)plot((median(ris), median(ris)), ylim())plot((mean(ris), mean(ris)), ylim())figure()hist(log(ris[ris!=0]), bins=100)plot((median(log(ris[ris!=0])), median(log(ris[ris!=0]))), ylim())plot((log(mean(ris[ris!=0])), log(mean(ris[ris!=0]))), ylim())print median(ris)from scipy.stats import skewprint skew(ris)where(ris==0)
# Out:
# 397164.51.05548899325
# (array([ 88, 181, 576, 694]),)

# %%
vars = [[ri_same_age, ri_different_age], [ri_same_medium, ri_different_medium], [ri_same_relationship, ri_different_relationship], [ri_male_male_same, ri_female_male_same, ri_male_female_same, ri_female_female_same, ri_male_male_diff, ri_female_male_diff, ri_male_female_diff, ri_female_female_diff]]medians = []freqs = []c = -1color_labels = ['blue','red','green','magenta','black','yellow']colors = []for i in vars:    c+=1    if type(i[0])==numpy.ndarray:        for j in i:            colors.append(color_labels[c])            medians.append(median(j))            freqs.append(len(j))    else:        colors.append(color_labels[c])        medians.append(median(i))        freqs.append(len(i))fig = figure()ax = fig.add_subplot(111)ax.scatter(asarray(freqs)/float(len(ris)), medians, c=colors)ylim(-10000, ylim[1])xlim(0,100)m, b, r, p, stderr = linregress(freqs, medians)x = arange(xlim()[0], xlim()[1])y = m*x+bplot(x,y)text(.1, .5, "y = %f*x+%.1f, R^2=%.2f, p=%.3f"%(m,b,r**2, p), transform = ax.transAxes)
# Out:
# <span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">TypeError</span>                                 Traceback (most recent call last)
# <span class="ansigreen">/home/alstottj/Code/Langley/&lt;ipython-input-416-2c487862cc75&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">     20</span> ax <span class="ansiyellow">=</span> fig<span class="ansiyellow">.</span>add_subplot<span class="ansiyellow">(</span><span class="ansicyan">111</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# ...

# %%
fig = plt.figure()ax = fig.add_subplot(111)ax.scatter(depths, ris)title("No Effect of Registration Interval on Number of Shares")xlabel('Depth')ylabel('Registraction Interval (s)')#ylim(-100000, ylim()[1])#xlim(-1, ylim()[1])#m, b, r, p, stderr = linregress(ds, ris)#x = arange(xlim()[0], xlim()[1])#y = m*x+b#ax.plot(x,y)m, b, r, p, stderr = linregress(depths, ris)#x = arange(xlim()[0], xlim()[1])#y = m*x+b#ax.plot(x,y)#text(.1, .5, "y = %.2f*x+%.1f, R^2=%.2f, p=%.3f"%(m,b,r**2, p), transform = ax.transAxes)savefig("figure%i.png"%z, dpi=300, bbox_inches='tight')z+=1fig = plt.figure()ax = fig.add_subplot(111)d1 = ris[depths==1]d2 = ris[depths==2]d3 = ris[depths==3]d4 = ris[depths==4]d5 = ris[depths==5]d6 = ris[depths==6]q = ax.boxplot([d1, d2, d3, d4, d5, d6], notch=True)xlabel("Generation in Invite Tree")ylabel("Registraction Interval (s)")p_krusks = []p_krusks.append(kruskal(d1, d2)[1])p_krusks.append(kruskal(d3, d2)[1])p_krusks.append(kruskal(d3, d4)[1])p_krusks.append(kruskal(d4, d5)[1])p_krusks.append(kruskal(d5, d6)[1])from rpy2.robjects.packages import importrfrom rpy2.robjects.vectors import FloatVectorstats = importr('stats')p_krusks = asarray(stats.p_adjust(FloatVector(p_krusks), method = 'holm'))print p_krusksprint median(ris)

# %%
ri_1_s = asarray([q for q in session.query(db.LangleyParticipant).\                        filter_by(Depth_in_Invite_Chain=1).\                        filter_by(Same_City_as_Parent=True).\                        filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).\                        values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()ri_1_d = asarray([q for q in session.query(db.LangleyParticipant).\                        filter_by(Depth_in_Invite_Chain=1).\                        filter_by(Same_City_as_Parent=False).\                        filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).\                        values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()ri_2_s = asarray([q for q in session.query(db.LangleyParticipant).\                        filter_by(Depth_in_Invite_Chain=2).\                        filter_by(Same_City_as_Parent=True).\                        filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).\                        values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()ri_2_d = asarray([q for q in session.query(db.LangleyParticipant).\                        filter_by(Depth_in_Invite_Chain=2).\                        filter_by(Same_City_as_Parent=False).\                        filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).\                        values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()ri_3_s = asarray([q for q in session.query(db.LangleyParticipant).\                        filter_by(Depth_in_Invite_Chain=3).\                        filter_by(Same_City_as_Parent=True).\                        filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).\                        values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()ri_3_d = asarray([q for q in session.query(db.LangleyParticipant).\                        filter_by(Depth_in_Invite_Chain=3).\                        filter_by(Same_City_as_Parent=False).\                        filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).\                        values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()ri_4_s = asarray([q for q in session.query(db.LangleyParticipant).\                        filter_by(Depth_in_Invite_Chain=4).\                        filter_by(Same_City_as_Parent=True).\                        filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).\                        values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()ri_4_d = asarray([q for q in session.query(db.LangleyParticipant).\                        filter_by(Depth_in_Invite_Chain=4).\                        filter_by(Same_City_as_Parent=False).\                        filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).\                        values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()ri_5_s = asarray([q for q in session.query(db.LangleyParticipant).\                        filter_by(Depth_in_Invite_Chain=5).\                        filter_by(Same_City_as_Parent=True).\                        filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).\                        values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()ri_5_d = asarray([q for q in session.query(db.LangleyParticipant).\                        filter_by(Depth_in_Invite_Chain=5).\                        filter_by(Same_City_as_Parent=False).\                        filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).\                        values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()ri_6_s = asarray([q for q in session.query(db.LangleyParticipant).\                        filter_by(Depth_in_Invite_Chain=6).\                        filter_by(Same_City_as_Parent=True).\                        filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).\                        values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()ri_6_d = asarray([q for q in session.query(db.LangleyParticipant).\                        filter_by(Depth_in_Invite_Chain=6).\                        filter_by(Same_City_as_Parent=False).\                        filter(db.LangleyParticipant.Parent_Child_Registration_Interval!=None).\                        values(getattr(db.LangleyParticipant, 'Parent_Child_Registration_Interval_Corrected'))]).flatten()                               fig = plt.figure()ax = fig.add_subplot(111)bp = ax.boxplot([ri_1_s, ri_2_s, ri_3_s, ri_4_s, ri_5_s, ri_6_s, ri_1_d, ri_2_d, ri_3_d, ri_4_d, ri_5_d, ri_6_d], notch=1)title("Registration Interval is Shorter for Females")ylabel('Recruiter-Recruited Registration Inverval(seconds)')#plt.setp(ax, xticklabels=["Male\nfrom Male", "Female\nfrom Male", "Male\nfrom Female", "Female\nfrom Female"])ylim(-10000, ylim()[1])#plt.setp(xtickNames, rotation=45, fontsize=8)from scipy.stats import kruskalp_krusks = []p_krusks.append(kruskal(ri_1_s, ri_2_s)[1])p_krusks.append(kruskal(ri_1_d, ri_1_s)[1])p_krusks.append(kruskal(ri_1_d, ri_2_d)[1])p_krusks.append(kruskal(ri_5_d, ri_6_d)[1])p_krusks.append(kruskal(ri_1_d, ri_6_d)[1])from rpy2.robjects.packages import importrfrom rpy2.robjects.vectors import FloatVectorstats = importr('stats')p_krusks = asarray(stats.p_adjust(FloatVector(p_krusks), method = 'holm'))print p_kruskssetp(bp['boxes'][:4], color='blue')setp(bp['boxes'][4], color='green')setp(bp['boxes'][5], color='black')setp(bp['boxes'][6:], color='red')savefig("figure%i.png"%z, dpi=300, bbox_inches='tight')z+=1fig = plt.figure()ax = fig.add_subplot(111)data = [ri_1_s, ri_2_s, ri_3_s, ri_4_s, ri_5_s, ri_6_s, ri_1_d, ri_2_d, ri_3_d, ri_4_d, ri_5_d, ri_6_d]data_freq = []ind = [1]width = 1for i in range(len(data)):    ind.append(ind[-1]+1.5)    data_freq.append(len(data[i]))ind = ind[:-1]ax.bar(ind, asarray(data_freq), width=width)from scipy.stats import chisquare#expected = sum([len(ri_male_male_same), len(ri_female_male_same), len(ri_male_female_same), len(ri_female_female_same)])/4print chisquare([len(ri_male_male_same), len(ri_female_male_same), len(ri_male_female_same), len(ri_female_female_same)])print chisquare([len(ri_male_male_diff), len(ri_female_male_diff), len(ri_male_female_diff), len(ri_female_female_diff)])from scipy.stats.stats import pearsonrprint pearsonr([len(ri_male_male_same), len(ri_female_male_same), len(ri_male_female_same), len(ri_female_female_same), len(ri_male_male_diff), len(ri_female_male_diff), len(ri_male_female_diff), len(ri_female_female_diff)], [median(ri_male_male_same), median(ri_female_male_same), median(ri_male_female_same), median(ri_female_female_same), median(ri_male_male_diff), median(ri_female_male_diff), median(ri_male_female_diff), median(ri_female_female_diff)])print pearsonr([len(ri_male_male_same), len(ri_female_male_same), len(ri_male_female_same), len(ri_female_female_same), len(ri_male_male_diff), len(ri_female_male_diff), len(ri_male_female_diff), len(ri_female_female_diff)], [mean(ri_male_male_same), mean(ri_female_male_same), mean(ri_male_female_same), mean(ri_female_female_same), mean(ri_male_male_diff), mean(ri_female_male_diff), mean(ri_male_female_diff), mean(ri_female_female_diff)])fig = plt.figure()ax = fig.add_subplot(111)freqs = [len(ri_male_male_same), len(ri_female_male_same), len(ri_male_female_same), len(ri_female_female_same), len(ri_male_male_diff), len(ri_female_male_diff), len(ri_male_female_diff), len(ri_female_female_diff)]freqs = asarray(freqs)/float(len(ris))medians = [median(ri_male_male_same), median(ri_female_male_same), median(ri_male_female_same), median(ri_female_female_same), median(ri_male_male_diff), median(ri_female_male_diff), median(ri_male_female_diff), median(ri_female_female_diff)]ax.scatter(freqs, medians)m, b, r, p, stderr = linregress(freqs, medians)print mprint b#x = arange(xlim()[0], xlim()[1])x = asarray([-.01, .4])y = m*x+bax.plot(x,y)text(.1, .5, "y = %f*x+%.1f, R^2=%.2f, p=%.3f"%(m,b,r**2, p), transform = ax.transAxes)
